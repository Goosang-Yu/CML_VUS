# %% [markdown]
# # **Supplementary Code 4**
# This notebook was used for analysis of NGS reads containing intended prime-editing and synonymous mutation marker. For more detail, please read Methods and Supplementary Information.
#
# Lead contact: Hyoungbum Henry Kim (hkim1@gmail.com)
#
# Technical contact: Goosang Yu (gsyu93@gmail.com), Yusang Jung (ys.jung@yuhs.ac)

# %% [markdown]
# ## Directory tree
#
# 📦Working directory
#  ┣ 📂data
#  ┃ ┣ 📂NGS_FASTQ_files
#  ┃ ┣ 📂NGS_frequency_table
#  ┃ ┃ ┣ 📜C4Bosutinib791.txt
#  ┃ ┃ ┣ 📜C4Control797.txt
#  ┃ ┃ ┗ 📜...
#  ┃ ┣ 📂read_counts
#  ┃ ┣ 📂statistics
#  ┃
#  ┣ 📂src
#  ┃ ┣ 📜Alignment.py
#  ┃ ┣ 📜VarCalling.py
#  ┃
#  ┣ 📂variants_info
#  ┃ ┣ 📜ex4_info.csv
#  ┃ ┣ 📜ex5_info.csv
#  ┃ ┣ 📜ex6_info.csv
#  ┃ ┣ 📜ex7_info.csv
#  ┃ ┣ 📜ex8_info.csv
#  ┃ ┣ 📜ex9_info.csv
#  ┃ ┣ 📜invivo_ex4_info.csv
#  ┃ ┗ 📜invivo_ex9_info.csv
#  ┃
#  ┗ 📜SuppleCode4.ipynb (this file)

# %% [markdown]
# # Requirements
# - CRISPResso2 (>= 2.x.x)
# - pandas

# %% [markdown]
# ## Variants calling and make read count file
# After running CRISPResso, generate the read count file. This is the process of creating the foundational file for all analyses.

# %%
import os
import pandas as pd
from tqdm import tqdm
from glob import glob

from src.Alignment import ABL1VUS
from src.VarCalling import make_count_file, read_statistics, combine_data, VariantFilter, VariantScore, Normalizer

# %%
# Make count files from frequency table

freq_tables = glob('data/frequency_table/*.txt')

for f in freq_tables:

    n_sample = os.path.basename(f).replace('.txt', '')
    exon_num = n_sample.split('Exon')[1][0]
    ref_info = f'variants_info/ex{exon_num}_info.csv'

    
    df_cnt = make_count_file(f, ref_info)
    df_cnt.to_csv(f'data/read_counts/Count_{n_sample}.csv', index=False)
# Out:
# [Info] Read counting: K562PE2_unedit_Exon5: 100%|██████████| 36438/36438 [00:03<00:00, 10306.87it/s]
# [Info] Read counting: K562PE4K_HTS_Exon4_Rep1_Asciminib: 100%|██████████| 1126274/1126274 [01:52<00:00, 9996.74it/s]
# [Info] Read counting: K562PE4K_HTS_Exon4_Rep1_Bosutinib: 100%|██████████| 1310545/1310545 [02:08<00:00, 10160.25it/s]
# [Info] Read counting: K562PE4K_HTS_Exon4_Rep1_Dasatinib: 100%|██████████| 1096266/1096266 [01:48<00:00, 10090.48it/s]
# [Info] Read counting: K562PE4K_HTS_Exon4_Rep1_DMSO: 100%|██████████| 1231441/1231441 [02:02<00:00, 10064.29it/s]
# [Info] Read counting: K562PE4K_HTS_Exon4_Rep1_Imatinib: 100%|██████████| 1290582/1290582 [02:08<00:00, 10016.11it/s]
# [Info] Read counting: K562PE4K_HTS_Exon4_Rep1_Nilotinib: 100%|██████████| 1059960/1059960 [01:47<00:00, 9905.26it/s]
# [Info] Read counting: K562PE4K_HTS_Exon4_Rep1_Ponatinib: 100%|██████████| 964463/964463 [01:36<00:00, 9955.14it/s]
# [Info] Read counting: K562PE4K_HTS_Exon4_Rep2_Asciminib: 100%|██████████| 1532951/1532951 [02:33<00:00, 9975.36it/s]
# [Info] Read counting: K562PE4K_HTS_Exon4_Rep2_Bosutinib: 100%|██████████| 1047010/1047010 [01:44<00:00, 9989.00it/s]
# [Info] Read counting: K562PE4K_HTS_Exon4_Rep2_Dasatinib: 100%|██████████| 1152683/1152683 [01:56<00:00, 9882.48it/s]
# [Info] Read counting: K562PE4K_HTS_Exon4_Rep2_DMSO: 100%|██████████| 1039115/1039115 [01:43<00:00, 10011.08it/s]
# [Info] Read counting: K562PE4K_HTS_Exon4_Rep2_Imatinib: 100%|██████████| 1220395/1220395 [02:02<00:00, 10001.29it/s]
# [Info] Read counting: K562PE4K_HTS_Exon4_Rep2_Nilotinib: 100%|██████████| 1379467/1379467 [02:19<00:00, 9900.44it/s]
# [Info] Read counting: K562PE4K_HTS_Exon4_Rep2_Ponatinib: 100%|██████████| 1131439/1131439 [01:52<00:00, 10086.10it/s]
# [Info] Read counting: K562PE4K_HTS_Exon5_Rep1_Asciminib: 100%|██████████| 284597/284597 [00:28<00:00, 9976.82it/s]
# [Info] Read counting: K562PE4K_HTS_Exon5_Rep1_Bosutinib: 100%|██████████| 190008/190008 [00:18<00:00, 10106.05it/s]
# [Info] Read counting: K562PE4K_HTS_Exon5_Rep1_Dasatinib: 100%|██████████| 234142/234142 [00:22<00:00, 10314.68it/s]
# [Info] Read counting: K562PE4K_HTS_Exon5_Rep1_DMSO: 100%|██████████| 243513/243513 [00:25<00:00, 9465.35it/s]
# [Info] Read counting: K562PE4K_HTS_Exon5_Rep1_Imatinib: 100%|██████████| 287436/287436 [00:29<00:00, 9680.27it/s]
# [Info] Read counting: K562PE4K_HTS_Exon5_Rep1_Nilotinib: 100%|██████████| 256333/256333 [00:26<00:00, 9838.81it/s]
# [Info] Read counting: K562PE4K_HTS_Exon5_Rep1_Ponatinib: 100%|██████████| 278063/278063 [00:27<00:00, 10126.57it/s]
# [Info] Read counting: K562PE4K_HTS_Exon5_Rep2_Asciminib: 100%|██████████| 272710/272710 [00:28<00:00, 9678.84it/s]
# [Info] Read counting: K562PE4K_HTS_Exon5_Rep2_Bosutinib: 100%|██████████| 236708/236708 [00:24<00:00, 9859.95it/s]
# [Info] Read counting: K562PE4K_HTS_Exon5_Rep2_Dasatinib: 100%|██████████| 225657/225657 [00:22<00:00, 10035.19it/s]
# [Info] Read counting: K562PE4K_HTS_Exon5_Rep2_DMSO: 100%|██████████| 265791/265791 [00:25<00:00, 10257.14it/s]
# [Info] Read counting: K562PE4K_HTS_Exon5_Rep2_Imatinib: 100%|██████████| 277963/277963 [00:27<00:00, 9990.56it/s]
# [Info] Read counting: K562PE4K_HTS_Exon5_Rep2_Nilotinib: 100%|██████████| 296082/296082 [00:30<00:00, 9726.70it/s]
# [Info] Read counting: K562PE4K_HTS_Exon5_Rep2_Ponatinib: 100%|██████████| 274884/274884 [00:27<00:00, 9907.80it/s]
# [Info] Read counting: K562PE4K_HTS_Exon6_Rep1_Asciminib: 100%|██████████| 384040/384040 [00:37<00:00, 10222.48it/s]
# [Info] Read counting: K562PE4K_HTS_Exon6_Rep1_Bosutinib: 100%|██████████| 435058/435058 [00:43<00:00, 9930.72it/s]
# [Info] Read counting: K562PE4K_HTS_Exon6_Rep1_Dasatinib: 100%|██████████| 2716509/2716509 [04:36<00:00, 9835.91it/s]
# [Info] Read counting: K562PE4K_HTS_Exon6_Rep1_DMSO: 100%|██████████| 321185/321185 [00:32<00:00, 9901.96it/s]
# [Info] Read counting: K562PE4K_HTS_Exon6_Rep1_Imatinib: 100%|██████████| 350757/350757 [00:35<00:00, 9771.77it/s]
# [Info] Read counting: K562PE4K_HTS_Exon6_Rep1_Nilotinib: 100%|██████████| 336212/336212 [00:34<00:00, 9755.02it/s]
# [Info] Read counting: K562PE4K_HTS_Exon6_Rep1_Ponatinib: 100%|██████████| 1517771/1517771 [02:32<00:00, 9953.15it/s]
# [Info] Read counting: K562PE4K_HTS_Exon6_Rep2_Asciminib: 100%|██████████| 446664/446664 [00:45<00:00, 9837.97it/s]
# [Info] Read counting: K562PE4K_HTS_Exon6_Rep2_Bosutinib: 100%|██████████| 512835/512835 [00:50<00:00, 10073.24it/s]
# [Info] Read counting: K562PE4K_HTS_Exon6_Rep2_Dasatinib: 100%|██████████| 437648/437648 [00:43<00:00, 9976.04it/s]
# [Info] Read counting: K562PE4K_HTS_Exon6_Rep2_DMSO: 100%|██████████| 308569/308569 [00:29<00:00, 10298.77it/s]
# [Info] Read counting: K562PE4K_HTS_Exon6_Rep2_Imatinib: 100%|██████████| 312844/312844 [00:32<00:00, 9572.49it/s]
# [Info] Read counting: K562PE4K_HTS_Exon6_Rep2_Nilotinib: 100%|██████████| 309247/309247 [00:32<00:00, 9487.04it/s]
# [Info] Read counting: K562PE4K_HTS_Exon6_Rep2_Ponatinib: 100%|██████████| 498472/498472 [00:50<00:00, 9869.09it/s]
# [Info] Read counting: K562PE4K_HTS_Exon7_Rep1_Asciminib: 100%|██████████| 295285/295285 [00:29<00:00, 9944.96it/s]
# [Info] Read counting: K562PE4K_HTS_Exon7_Rep1_Bosutinib: 100%|██████████| 307535/307535 [00:31<00:00, 9918.45it/s]
# [Info] Read counting: K562PE4K_HTS_Exon7_Rep1_Dasatinib: 100%|██████████| 279471/279471 [00:27<00:00, 10150.44it/s]
# [Info] Read counting: K562PE4K_HTS_Exon7_Rep1_DMSO: 100%|██████████| 269842/269842 [00:27<00:00, 9866.02it/s]
# [Info] Read counting: K562PE4K_HTS_Exon7_Rep1_Imatinib: 100%|██████████| 286591/286591 [00:28<00:00, 10105.36it/s]
# [Info] Read counting: K562PE4K_HTS_Exon7_Rep1_Nilotinib: 100%|██████████| 274591/274591 [00:26<00:00, 10246.24it/s]
# [Info] Read counting: K562PE4K_HTS_Exon7_Rep1_Ponatinib: 100%|██████████| 214263/214263 [00:21<00:00, 9740.57it/s]
# [Info] Read counting: K562PE4K_HTS_Exon7_Rep2_Asciminib: 100%|██████████| 258860/258860 [00:25<00:00, 10070.55it/s]
# [Info] Read counting: K562PE4K_HTS_Exon7_Rep2_Bosutinib: 100%|██████████| 266911/266911 [00:26<00:00, 10180.07it/s]
# [Info] Read counting: K562PE4K_HTS_Exon7_Rep2_Dasatinib: 100%|██████████| 279166/279166 [00:28<00:00, 9781.47it/s]
# [Info] Read counting: K562PE4K_HTS_Exon7_Rep2_DMSO: 100%|██████████| 258866/258866 [00:25<00:00, 10049.66it/s]
# [Info] Read counting: K562PE4K_HTS_Exon7_Rep2_Imatinib: 100%|██████████| 264447/264447 [00:25<00:00, 10239.35it/s]
# [Info] Read counting: K562PE4K_HTS_Exon7_Rep2_Nilotinib: 100%|██████████| 269939/269939 [00:28<00:00, 9633.69it/s]
# [Info] Read counting: K562PE4K_HTS_Exon7_Rep2_Ponatinib: 100%|██████████| 267912/267912 [00:27<00:00, 9901.03it/s]
# [Info] Read counting: K562PE4K_HTS_Exon8_Rep1_Asciminib: 100%|██████████| 265345/265345 [00:26<00:00, 10182.20it/s]
# [Info] Read counting: K562PE4K_HTS_Exon8_Rep1_Bosutinib: 100%|██████████| 258301/258301 [00:25<00:00, 10235.26it/s]
# [Info] Read counting: K562PE4K_HTS_Exon8_Rep1_Dasatinib: 100%|██████████| 276786/276786 [00:27<00:00, 10141.14it/s]
# [Info] Read counting: K562PE4K_HTS_Exon8_Rep1_DMSO: 100%|██████████| 245955/245955 [00:24<00:00, 10052.18it/s]
# [Info] Read counting: K562PE4K_HTS_Exon8_Rep1_Imatinib: 100%|██████████| 262176/262176 [00:25<00:00, 10159.07it/s]
# [Info] Read counting: K562PE4K_HTS_Exon8_Rep1_Nilotinib: 100%|██████████| 243650/243650 [00:23<00:00, 10269.39it/s]
# [Info] Read counting: K562PE4K_HTS_Exon8_Rep1_Ponatinib: 100%|██████████| 257091/257091 [00:26<00:00, 9767.50it/s]
# [Info] Read counting: K562PE4K_HTS_Exon8_Rep2_Asciminib: 100%|██████████| 262382/262382 [00:26<00:00, 9908.69it/s]
# [Info] Read counting: K562PE4K_HTS_Exon8_Rep2_Bosutinib: 100%|██████████| 268718/268718 [00:26<00:00, 10072.83it/s]
# [Info] Read counting: K562PE4K_HTS_Exon8_Rep2_Dasatinib: 100%|██████████| 237887/237887 [00:23<00:00, 10151.71it/s]
# [Info] Read counting: K562PE4K_HTS_Exon8_Rep2_DMSO: 100%|██████████| 244360/244360 [00:24<00:00, 9938.37it/s]
# [Info] Read counting: K562PE4K_HTS_Exon8_Rep2_Imatinib: 100%|██████████| 235388/235388 [00:23<00:00, 9958.89it/s]
# [Info] Read counting: K562PE4K_HTS_Exon8_Rep2_Nilotinib: 100%|██████████| 247051/247051 [00:24<00:00, 10136.34it/s]
# [Info] Read counting: K562PE4K_HTS_Exon8_Rep2_Ponatinib: 100%|██████████| 239411/239411 [00:24<00:00, 9665.48it/s]
# [Info] Read counting: K562PE4K_HTS_Exon9_Rep1_Asciminib: 100%|██████████| 41352/41352 [00:04<00:00, 9752.51it/s]
# [Info] Read counting: K562PE4K_HTS_Exon9_Rep1_Bosutinib: 100%|██████████| 42781/42781 [00:04<00:00, 9976.49it/s]
# [Info] Read counting: K562PE4K_HTS_Exon9_Rep1_Dasatinib: 100%|██████████| 42007/42007 [00:04<00:00, 10041.81it/s]
# [Info] Read counting: K562PE4K_HTS_Exon9_Rep1_DMSO: 100%|██████████| 122031/122031 [00:12<00:00, 10034.79it/s]
# [Info] Read counting: K562PE4K_HTS_Exon9_Rep1_Imatinib: 100%|██████████| 33500/33500 [00:03<00:00, 10096.21it/s]
# [Info] Read counting: K562PE4K_HTS_Exon9_Rep1_Nilotinib: 100%|██████████| 41305/41305 [00:04<00:00, 10115.35it/s]
# [Info] Read counting: K562PE4K_HTS_Exon9_Rep1_Ponatinib: 100%|██████████| 39799/39799 [00:03<00:00, 10186.78it/s]
# [Info] Read counting: K562PE4K_HTS_Exon9_Rep2_Asciminib: 100%|██████████| 36974/36974 [00:03<00:00, 10323.60it/s]
# [Info] Read counting: K562PE4K_HTS_Exon9_Rep2_Bosutinib: 100%|██████████| 45966/45966 [00:04<00:00, 10088.16it/s]
# [Info] Read counting: K562PE4K_HTS_Exon9_Rep2_Dasatinib: 100%|██████████| 38426/38426 [00:03<00:00, 10219.37it/s]
# [Info] Read counting: K562PE4K_HTS_Exon9_Rep2_DMSO: 100%|██████████| 118661/118661 [00:12<00:00, 9807.51it/s]
# [Info] Read counting: K562PE4K_HTS_Exon9_Rep2_Imatinib: 100%|██████████| 42007/42007 [00:04<00:00, 9420.70it/s]
# [Info] Read counting: K562PE4K_HTS_Exon9_Rep2_Nilotinib: 100%|██████████| 40880/40880 [00:04<00:00, 10020.60it/s]
# [Info] Read counting: K562PE4K_HTS_Exon9_Rep2_Ponatinib: 100%|██████████| 48962/48962 [00:04<00:00, 9903.26it/s]
# [Info] Read counting: K562PE4K_unedit_Exon4: 100%|██████████| 591633/591633 [00:58<00:00, 10092.88it/s]
# [Info] Read counting: K562PE4K_unedit_Exon5: 100%|██████████| 33839/33839 [00:03<00:00, 10006.56it/s]
# [Info] Read counting: K562PE4K_unedit_Exon6: 100%|██████████| 352558/352558 [00:35<00:00, 10005.75it/s]
# [Info] Read counting: K562PE4K_unedit_Exon7: 100%|██████████| 361164/361164 [00:35<00:00, 10194.95it/s]
# [Info] Read counting: K562PE4K_unedit_Exon8: 100%|██████████| 332840/332840 [00:32<00:00, 10143.37it/s]
# [Info] Read counting: K562PE4K_unedit_Exon9: 100%|██████████| 31833/31833 [00:03<00:00, 10103.50it/s]
# [Info] Read counting: KCL22PE4K_unedit_Exon5: 100%|██████████| 45978/45978 [00:04<00:00, 10070.60it/s]

# %% [markdown]
# ## Significance analysis
# Compare the prime-edited sample with the unedited sample to calculate the odds ratio and Fisher's exact test p-value for each variant.

# %%
# Calculate statistics with read count for each variants

dict_samples = {
    'KCLPE4K_DoseControl_Exon5_Rep1': {
        'test'  : 'Count_KCLPE4K_DoseControl_Exon5_Rep1_DMSO',
        'unedit': 'Count_KCLPE4K_unedit_Exon5',
    },
    'KCLPE4K_DoseControl_Exon5_Rep2': {
        'test'  : 'Count_KCLPE4K_DoseControl_Exon5_Rep2_DMSO',
        'unedit': 'Count_KCLPE4K_unedit_Exon5',
    },
}

for sample in dict_samples:
    
    test_file       = 'data/read_counts/' + dict_samples[sample]['test'] + '.csv'
    background_file = 'data/read_counts/' + dict_samples[sample]['unedit'] + '.csv'

    df_stats = read_statistics(test_file, background_file)

    df_stats.to_csv(f'data/statistics/Stat_{sample}_DMSO.csv', index=False)
# Out:
# Analysis: Count_KCLPE4K_DoseControl_Exon5_Rep1_DMSO
# Analysis: Count_KCLPE4K_DoseControl_Exon5_Rep2_DMSO

# %% [markdown]
# ## DMSO vs TKI response analysis
# Analysis for resistance to drugs
#
# - Test: Making variants using Prime editing for 20 days, followed by 10 days of TKI treatment.
# - Control: Making variants using Prime editing for 20 days, followed by 10 days of DMSO treatment.

# %%
# KCL screening
# Filtering variants and calculate normalized log 2 fold changes

list_sample = [
    ['KCLPE4K_Dose0.1_Exon5_Rep1_Dasatinib',  'KCLPE4K_Dose0.1_Exon5_Rep2_Dasatinib',],
    ['KCLPE4K_Dose0.2_Exon5_Rep1_Ponatinib',  'KCLPE4K_Dose0.2_Exon5_Rep2_Ponatinib',],
    ['KCLPE4K_Dose0.4_Exon5_Rep1_Dasatinib',  'KCLPE4K_Dose0.4_Exon5_Rep2_Dasatinib',],
    ['KCLPE4K_Dose0.7_Exon5_Rep1_Ponatinib',  'KCLPE4K_Dose0.7_Exon5_Rep2_Ponatinib',],
    ['KCLPE4K_Dose100_Exon5_Rep1_Imatinib',   'KCLPE4K_Dose100_Exon5_Rep2_Imatinib',],
    ['KCLPE4K_Dose10_Exon5_Rep1_Asciminib',   'KCLPE4K_Dose10_Exon5_Rep2_Asciminib',],
    ['KCLPE4K_Dose2.5_Exon5_Rep1_Bosutinib',  'KCLPE4K_Dose2.5_Exon5_Rep2_Bosutinib',],
    ['KCLPE4K_Dose2.5_Exon5_Rep1_Nilotinib',  'KCLPE4K_Dose2.5_Exon5_Rep2_Nilotinib',],
    ['KCLPE4K_Dose50_Exon5_Rep1_Imatinib',    'KCLPE4K_Dose50_Exon5_Rep2_Imatinib',],
    ['KCLPE4K_Dose5_Exon5_Rep1_Asciminib',    'KCLPE4K_Dose5_Exon5_Rep2_Asciminib',],
    ['KCLPE4K_Dose7.5_Exon5_Rep1_Bosutinib',  'KCLPE4K_Dose7.5_Exon5_Rep2_Bosutinib',],
    ['KCLPE4K_Dose8_Exon5_Rep1_Nilotinib',    'KCLPE4K_Dose8_Exon5_Rep2_Nilotinib',],
    ]


lws_frac = 0.15

for samples in list_sample:

    r1 = samples[0]
    r2 = samples[1]

    test_r1 = f'data/read_counts/Count_{r1}.csv'
    test_r2 = f'data/read_counts/Count_{r2}.csv'

    control_r1 = f'data/statistics/Stat_KCLPE4K_DoseControl_Exon5_Rep1_DMSO.csv'
    control_r2 = f'data/statistics/Stat_KCLPE4K_DoseControl_Exon5_Rep2_DMSO.csv'
    
    df_rep1, df_rep2 = VariantFilter(test_r1, test_r2, control_r1, control_r2).filter(OR_cutoff=2, p_cutoff=0.05, rpm_cutoff=10)

    normal = Normalizer()

    # LOWESS regression normalization
    df_nor1 = normal.lowess(df_rep1, frac=lws_frac)
    df_nor2 = normal.lowess(df_rep2, frac=lws_frac)

    df_nor1.to_csv(f'data/statistics/Filtered_{r1}.csv', index=False)
    df_nor2.to_csv(f'data/statistics/Filtered_{r2}.csv', index=False)

    rep_1 = f'data/statistics/Filtered_{r1}.csv'
    rep_2 = f'data/statistics/Filtered_{r2}.csv'

    # Score calculation 함수 불러오기
    score = VariantScore()

    adjus_LFC = score.calculate(rep_1, rep_2, var_type='SNV')
    res_score = score.calculate(rep_1, rep_2, var_type='AA')

    n_sample = r1.replace('Rep1_', '')

    adjus_LFC.to_csv(f'data/adjusted_LFC/AdjustedLFC_{n_sample}.csv')
    res_score.to_csv(f'data/resistance_score/ResistanceScore_{n_sample}.csv')
