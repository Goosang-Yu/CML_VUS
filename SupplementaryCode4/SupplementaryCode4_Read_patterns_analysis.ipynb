# %% [markdown]
# # Read patterns analysis
#
# Screening NGS 결과를 보면, SynPrime이 정확히 일어난 것 뿐만 아니라, 전혀 다른 read pattern이 나타나는 것들이 있다. 이러한 read pattern을 분석할 때 사용한 코드를 정리한 것.

# %%
import os
import pandas as pd
import pygwalker as pyg
from src.VarCalling import ReadPatternAnalyzer
from tqdm import tqdm
from glob import glob

# %%
rpa = ReadPatternAnalyzer()

files = glob('data/frequency_table/*KCL*.txt')

for freq_table in tqdm(files,
                       total = len(files),
                       desc = 'Read Pattern Analyzer', ## 진행률 앞쪽 출력 문장
                       ncols = 70,                     ## 진행률 출력 폭 조절
                       ascii = ' =',                   ## 바 모양, 첫 번째 문자는 공백이어야 작동
                      ):
    
    sample   = os.path.basename(freq_table).replace('.txt', '')
    exon_num = sample.split('Exon')[1][0]
    ref_info = f'variants_info/ex{exon_num}_info.csv'

    df_out = rpa.run(freq_table, ref_info)
    df_out.to_csv(f'data/read_patterns/{sample}_patterns.csv', index=False)
# Out:
# Read Pattern Analyzer: 100%|==========| 28/28 [31:20<00:00, 67.17s/it]

# %%
df = pd.read_csv('data/read_patterns/K562PE4K_HTS_Exon5_Rep1_DMSO_patterns.csv')
df
# Out:
#          #Reads     %Reads       mut_type    mut_class
# 0       5394215  47.116323      WT_refseq    WT_refseq
# 1        530543   4.634082  Intended_only  Single_edit
# 2        157719   1.377613           sub1         sub1
# 3        149326   1.304303          SynPE        SynPE
# 4        127368   1.112509          SynPE        SynPE
# ...         ...        ...            ...          ...
# 243508        1   0.000009           sub5     sub5more
# 243509        1   0.000009           sub4         sub4
# 243510        1   0.000009           sub5     sub5more
# 243511        1   0.000009           sub4         sub4
# 243512        1   0.000009           sub7     sub5more
#
# [243513 rows x 4 columns]

# %%
gwalger = pyg.walk(df)
# Out:
# Box(children=(HTML(value='<div id="ifr-pyg-000618104e77eb84tuIOWxy4JED1Tcwl" style="height: auto">\n    <head>…

# %%
# summary file 만들기

read_type = '%Reads' # '#Reads' or '%Reads'

files = glob('data/read_patterns/*unedit*')
dict_summary = {}

for pattern_file in tqdm(files, total = len(files),
                       desc = 'Read Pattern Summary',  ## 진행률 앞쪽 출력 문장
                       ncols = 100,                    ## 진행률 출력 폭 조절
                       ascii = ' =',                   ## 바 모양, 첫 번째 문자는 공백이어야 작동
                      ):
    
    df_pattern  = pd.read_csv(pattern_file)
    sample_name = os.path.basename(pattern_file).replace('.csv', '')
    dict_temp   = {}

    for idx in tqdm(df_pattern.index, total=len(df_pattern.index),
                    desc='Summarize mut classes',
                    ncols=100,
                    leave=False,
                    ):
        data = df_pattern.loc[idx]

        try   : dict_temp[data.mut_class] += data[read_type]
        except: dict_temp[data.mut_class]  = data[read_type]

    dict_summary[sample_name] = dict_temp

df_summary = pd.DataFrame.from_dict(dict_summary, orient='index')
df_summary
# Out:
# Read Pattern Summary:   0%|                                                  | 0/26 [00:00<?, ?it/s]
# Read Pattern Summary: 100%|=========================================| 26/26 [08:01<00:00, 18.50s/it]
#                                            WT_refseq    sub1  Single_edit  \
# K562PE2_unedit_Exon5_patterns             18840658.0  255687     602032.0
# K562PE4K_unedit_Exon4_patterns            16650729.0  351284    2412249.0
# K562PE4K_unedit_Exon5_patterns            18798667.0  220120     553037.0
# K562PE4K_unedit_Exon6_patterns            22405288.0  371982    2350896.0
# K562PE4K_unedit_Exon7_patterns            17886596.0  248499    1903222.0
# K562PE4K_unedit_Exon8_patterns            18545897.0  310245    1624535.0
# K562PE4K_unedit_Exon9_patterns            12589496.0  148423    1822776.0
# K562PE4K_unedit_miniseq_Exon5_patterns      291969.0    3229      19452.0
# K562PE4K_unedit_miniseq_Exon6_patterns      225628.0    6100      40106.0
# K562PE4K_unedit_miniseq_Exon7_patterns      193485.0    5560      51860.0
# K562PE4K_unedit_miniseq_Exon8_patterns      243181.0    6072      39383.0
# K562PE4K_unedit_miniseq_Exon9_patterns      326620.0    8824      62924.0
# K562WT_Exon5_unedit_patterns                262950.0    3138      15664.0
# K562WT_Exon6_unedit_patterns                382757.0    9889      63098.0
# K562WT_Exon7_unedit_patterns                333069.0    7523      51732.0
# K562WT_Exon8_unedit_patterns                396763.0    8247      44368.0
# K562WT_Exon9_unedit_patterns                252921.0    4614      56513.0
# K562WT_unedit_Exon5_patterns              21597439.0  272662    1281094.0
# K562WT_unedit_Exon6_patterns              23197805.0  506495    2977655.0
# K562WT_unedit_Exon7_patterns              23896819.0  301890    2681923.0
# K562WT_unedit_Exon8_patterns              23037563.0  339730    2406048.0
# K562WT_unedit_Exon9_patterns              15188199.0  189323    3095593.0
# KCL22PE4K_unedit_Exon5_patterns           20928813.0  250635     589377.0
# KCLPE4K_unedit_Exon5_patterns             20928813.0  250635     589377.0
# K562PE4K_unedit_miniseq_Exon4-1_patterns         NaN   40320          NaN
# K562PE4K_unedit_miniseq_Exon4-2_patterns         NaN   60888          NaN
#
#                                             ins    del     SynPE    sub2  \
# K562PE2_unedit_Exon5_patterns             14236  11871  138810.0   31295
# K562PE4K_unedit_Exon4_patterns             5106  57398    1814.0  431956
# K562PE4K_unedit_Exon5_patterns            14412  13609  131098.0   24341
# K562PE4K_unedit_Exon6_patterns             2774  19153   91018.0  320240
# K562PE4K_unedit_Exon7_patterns             2469  26801   13396.0  246514
# K562PE4K_unedit_Exon8_patterns             1700  14522    5050.0  212515
# K562PE4K_unedit_Exon9_patterns              488   7818    4214.0   92713
# K562PE4K_unedit_miniseq_Exon5_patterns      199    751     990.0    2916
# K562PE4K_unedit_miniseq_Exon6_patterns       33    862    3064.0    9866
# K562PE4K_unedit_miniseq_Exon7_patterns       27   1123     246.0   17184
# K562PE4K_unedit_miniseq_Exon8_patterns       21    643     103.0    8924
# K562PE4K_unedit_miniseq_Exon9_patterns        5    645     171.0    8074
# K562WT_Exon5_unedit_patterns                126    605    1090.0    1382
# K562WT_Exon6_unedit_patterns                 34   1303     943.0   15643
# K562WT_Exon7_unedit_patterns                 29   1428     283.0   13759
# K562WT_Exon8_unedit_patterns                 26   1054     137.0    9787
# K562WT_Exon9_unedit_patterns                  4    587      55.0    5060
# K562WT_unedit_Exon5_patterns              14444  22493   86998.0  156363
# K562WT_unedit_Exon6_patterns               2759  24891   58791.0  542575
# K562WT_unedit_Exon7_patterns               3174  39436   21810.0  506777
# K562WT_unedit_Exon8_patterns               1932  23219    6825.0  532352
# K562WT_unedit_Exon9_patterns                466   8623    1142.0  172687
# KCL22PE4K_unedit_Exon5_patterns           15285  14733  233637.0   34664
# KCLPE4K_unedit_Exon5_patterns             15285  14733  233637.0   34664
# K562PE4K_unedit_miniseq_Exon4-1_patterns     36    926       NaN    7837
# K562PE4K_unedit_miniseq_Exon4-2_patterns    323  12897       NaN   16165
#
#                                           sub5more    sub3    sub4  Complex  \
# K562PE2_unedit_Exon5_patterns                 9646   13367   13035     37.0
# K562PE4K_unedit_Exon4_patterns              212753  150058   85691     33.0
# K562PE4K_unedit_Exon5_patterns               10101   11088    9448     38.0
# K562PE4K_unedit_Exon6_patterns              132442   94178   50908    197.0
# K562PE4K_unedit_Exon7_patterns              162258   79436   47835    142.0
# K562PE4K_unedit_Exon8_patterns              154886   80240   50615     11.0
# K562PE4K_unedit_Exon9_patterns                3059    8667    2965      3.0
# K562PE4K_unedit_miniseq_Exon5_patterns        1244    1119     664      NaN
# K562PE4K_unedit_miniseq_Exon6_patterns        5986    4255    2366      8.0
# K562PE4K_unedit_miniseq_Exon7_patterns       15540    8231    4974     12.0
# K562PE4K_unedit_miniseq_Exon8_patterns        5870    3599    2136      1.0
# K562PE4K_unedit_miniseq_Exon9_patterns        1236    1694     775      NaN
# K562WT_Exon5_unedit_patterns                   105     354     200      1.0
# K562WT_Exon6_unedit_patterns                  7111    6341    3625      NaN
# K562WT_Exon7_unedit_patterns                  9019    6244    3881      NaN
# K562WT_Exon8_unedit_patterns                  6244    4484    2659      NaN
# K562WT_Exon9_unedit_patterns                    88     735     209      NaN
# K562WT_unedit_Exon5_patterns                 34768   51477   28649     13.0
# K562WT_unedit_Exon6_patterns                244012  192555  106670    173.0
# K562WT_unedit_Exon7_patterns                472251  234689  149321     78.0
# K562WT_unedit_Exon8_patterns                499718  268257  173823      4.0
# K562WT_unedit_Exon9_patterns                  6096   17080    5932      6.0
# KCL22PE4K_unedit_Exon5_patterns              12709   25701   28419     32.0
# KCLPE4K_unedit_Exon5_patterns                12709   25701   28419     32.0
# K562PE4K_unedit_miniseq_Exon4-1_patterns      4778    3218    1807      3.0
# K562PE4K_unedit_miniseq_Exon4-2_patterns      9776    6676    3777     47.0
#
#                                               sub0
# K562PE2_unedit_Exon5_patterns                  NaN
# K562PE4K_unedit_Exon4_patterns                 NaN
# K562PE4K_unedit_Exon5_patterns                 NaN
# K562PE4K_unedit_Exon6_patterns                 NaN
# K562PE4K_unedit_Exon7_patterns                 NaN
# K562PE4K_unedit_Exon8_patterns                 NaN
# K562PE4K_unedit_Exon9_patterns                 NaN
# K562PE4K_unedit_miniseq_Exon5_patterns         NaN
# K562PE4K_unedit_miniseq_Exon6_patterns         NaN
# K562PE4K_unedit_miniseq_Exon7_patterns         NaN
# K562PE4K_unedit_miniseq_Exon8_patterns         NaN
# K562PE4K_unedit_miniseq_Exon9_patterns         NaN
# K562WT_Exon5_unedit_patterns                   NaN
# K562WT_Exon6_unedit_patterns                   NaN
# K562WT_Exon7_unedit_patterns                   NaN
# K562WT_Exon8_unedit_patterns                   NaN
# K562WT_Exon9_unedit_patterns                   NaN
# K562WT_unedit_Exon5_patterns                   NaN
# K562WT_unedit_Exon6_patterns                   NaN
# K562WT_unedit_Exon7_patterns                   NaN
# K562WT_unedit_Exon8_patterns                   NaN
# K562WT_unedit_Exon9_patterns                   NaN
# KCL22PE4K_unedit_Exon5_patterns                NaN
# KCLPE4K_unedit_Exon5_patterns                  NaN
# K562PE4K_unedit_miniseq_Exon4-1_patterns  265295.0
# K562PE4K_unedit_miniseq_Exon4-2_patterns  219921.0

# %%
df_summary.to_csv('reads_patterns_summary_percent_KCLonly.csv')

# %% [markdown]
# ## K562 WT cell (No PE expressing) analysis

# %%
rpa = ReadPatternAnalyzer()

files = glob('data/frequency_table_K562WT_unedit/*.txt')

for freq_table in tqdm(files,
                       total = len(files),
                       desc = 'Read Pattern Analyzer', ## 진행률 앞쪽 출력 문장
                       ncols = 100,                    ## 진행률 출력 폭 조절
                       ascii = ' =',                   ## 바 모양, 첫 번째 문자는 공백이어야 작동
                      ):
    
    sample   = os.path.basename(freq_table).replace('.txt', '')
    exon_num = sample.split('Exon')[1][0]
    ref_info = f'variants_info/ex{exon_num}_info.csv'

    df_out = rpa.run(freq_table, ref_info)
    df_out.to_csv(f'data/read_patterns/{sample}_patterns.csv', index=False)
# Out:
# Read Pattern Analyzer: 100%|========================================| 10/10 [06:39<00:00, 39.94s/it]

# %%
# summary file 만들기

files = glob('data/read_patterns/K562WT*')
dict_summary = {}

for pattern_file in tqdm(files, total = len(files),
                       desc = 'Read Pattern Summary',  ## 진행률 앞쪽 출력 문장
                       ncols = 100,                    ## 진행률 출력 폭 조절
                       ascii = ' =',                   ## 바 모양, 첫 번째 문자는 공백이어야 작동
                      ):
    
    df_pattern  = pd.read_csv(pattern_file)
    sample_name = os.path.basename(pattern_file).replace('.csv', '')
    dict_temp   = {}

    for idx in tqdm(df_pattern.index, total=len(df_pattern.index),
                    desc='Summarize mut classes',
                    ncols=100,
                    leave=False,
                    ):
        data = df_pattern.loc[idx]

        try   : dict_temp[data.mut_class] += data['%Reads']
        except: dict_temp[data.mut_class]  = data['%Reads']

    dict_summary[sample_name] = dict_temp

df_summary = pd.DataFrame.from_dict(dict_summary, orient='index')
df_summary
# Out:
# Read Pattern Summary: 100%|=========================================| 10/10 [04:19<00:00, 26.00s/it]
#                               WT_refseq  Single_edit      sub1       del  \
# K562WT_Exon5_unedit_patterns  92.064492     5.484306  1.098682  0.211824
# K562WT_Exon6_unedit_patterns  77.995248    12.857620  2.015104  0.265515
# K562WT_Exon7_unedit_patterns  78.008136    12.116159  1.761963  0.334452
# K562WT_Exon8_unedit_patterns  83.746087     9.364901  1.740722  0.222471
# K562WT_Exon9_unedit_patterns  78.844152    17.617041  1.438342  0.182988
# K562WT_unedit_Exon5_patterns  91.722892     5.440721  1.157977  0.095526
# K562WT_unedit_Exon6_patterns  83.282429    10.690078  1.818367  0.089361
# K562WT_unedit_Exon7_patterns  84.416692     9.474025  1.066441  0.139310
# K562WT_unedit_Exon8_patterns  84.419236     8.816763  1.244912  0.085084
# K562WT_unedit_Exon9_patterns  81.284878    16.567132  1.013227  0.046149
#
#                                  SynPE       ins      sub2      sub3  \
# K562WT_Exon5_unedit_patterns  0.381633  0.044115  0.483868  0.123943
# K562WT_Exon6_unedit_patterns  0.192157  0.006928  3.187609  1.292120
# K562WT_Exon7_unedit_patterns  0.066281  0.006792  3.222497  1.462408
# K562WT_Exon8_unedit_patterns  0.028917  0.005488  2.065775  0.946453
# K562WT_Exon9_unedit_patterns  0.017145  0.001247  1.577376  0.229125
# K562WT_unedit_Exon5_patterns  0.369475  0.061343  0.664063  0.218619
# K562WT_unedit_Exon6_patterns  0.211066  0.009905  1.947898  0.691292
# K562WT_unedit_Exon7_patterns  0.077045  0.011212  1.790215  0.829050
# K562WT_unedit_Exon8_patterns  0.025010  0.007080  1.950760  0.983005
# K562WT_unedit_Exon9_patterns  0.006112  0.002494  0.924194  0.091410
#
#                               sub5more      sub4   Complex
# K562WT_Exon5_unedit_patterns  0.036763  0.070024  0.000350
# K562WT_Exon6_unedit_patterns  1.449024  0.738674       NaN
# K562WT_Exon7_unedit_patterns  2.112341  0.908970       NaN
# K562WT_Exon8_unedit_patterns  1.317942  0.561244       NaN
# K562WT_Exon9_unedit_patterns  0.027433  0.065152       NaN
# K562WT_unedit_Exon5_patterns  0.147657  0.121670  0.000055
# K562WT_unedit_Exon6_patterns  0.876027  0.382956  0.000621
# K562WT_unedit_Exon7_patterns  1.668250  0.527484  0.000276
# K562WT_unedit_Exon8_patterns  1.831175  0.636960  0.000015
# K562WT_unedit_Exon9_patterns  0.032625  0.031747  0.000032

# %%
df_summary.to_csv('K562WT_ReadPatterns.csv')

# %% [markdown]
# ## PCR cycle에 따른 분석

# %%
rpa = ReadPatternAnalyzer()

files = glob('data/frequency_table/PCR*.txt')

for freq_table in tqdm(files,
                       total = len(files),
                       desc = 'Read Pattern Analyzer', ## 진행률 앞쪽 출력 문장
                       ncols = 100,                    ## 진행률 출력 폭 조절
                       ascii = ' =',                   ## 바 모양, 첫 번째 문자는 공백이어야 작동
                      ):
    
    sample   = os.path.basename(freq_table).replace('.txt', '')
    exon_num = sample.split('Exon')[1][0]
    ref_info = f'variants_info/ex{exon_num}_info.csv'

    df_out = rpa.run(freq_table, ref_info)
    df_out.to_csv(f'data/read_patterns/{sample}_patterns.csv', index=False)
# Out:
# Read Pattern Analyzer: 100%|==========================================| 6/6 [02:18<00:00, 23.15s/it]

# %%
# summary file 만들기

files = glob('data/read_patterns/PCR*')
dict_summary = {}

for pattern_file in tqdm(files, total = len(files),
                       desc = 'Read Pattern Summary',  ## 진행률 앞쪽 출력 문장
                       ncols = 100,                    ## 진행률 출력 폭 조절
                       ascii = ' =',                   ## 바 모양, 첫 번째 문자는 공백이어야 작동
                      ):
    
    df_pattern  = pd.read_csv(pattern_file)
    sample_name = os.path.basename(pattern_file).replace('.csv', '')
    dict_temp   = {}

    for idx in tqdm(df_pattern.index, total=len(df_pattern.index),
                    desc='Summarize mut classes',
                    ncols=100,
                    leave=False,
                    ):
        data = df_pattern.loc[idx]

        try   : dict_temp[data.mut_class] += data['%Reads']
        except: dict_temp[data.mut_class]  = data['%Reads']

    dict_summary[sample_name] = dict_temp

df_summary = pd.DataFrame.from_dict(dict_summary, orient='index')
df_summary
# Out:
# Read Pattern Summary: 100%|===========================================| 6/6 [01:40<00:00, 16.74s/it]
#                                                   WT_refseq      SynPE  \
# PCR17cycle_K562PE4K_HTS_Exon5_Rep1_DMSO_patterns  55.408465  32.359899
# PCR17cycle_K562PE4K_HTS_Exon5_Rep2_DMSO_patterns  55.494765  32.225330
# PCR20cycle_K562PE4K_HTS_Exon5_Rep1_DMSO_patterns  56.339116  31.756827
# PCR20cycle_K562PE4K_HTS_Exon5_Rep2_DMSO_patterns  54.377200  32.716031
# PCR23cycle_K562PE4K_HTS_Exon5_Rep1_DMSO_patterns  55.269850  31.843589
# PCR23cycle_K562PE4K_HTS_Exon5_Rep2_DMSO_patterns  53.700806  33.243758
#
#                                                   Single_edit      sub1  \
# PCR17cycle_K562PE4K_HTS_Exon5_Rep1_DMSO_patterns     3.321113  0.626887
# PCR17cycle_K562PE4K_HTS_Exon5_Rep2_DMSO_patterns     3.428690  0.681515
# PCR20cycle_K562PE4K_HTS_Exon5_Rep1_DMSO_patterns     3.355387  0.679239
# PCR20cycle_K562PE4K_HTS_Exon5_Rep2_DMSO_patterns     3.505689  0.654098
# PCR23cycle_K562PE4K_HTS_Exon5_Rep1_DMSO_patterns     3.717663  0.720033
# PCR23cycle_K562PE4K_HTS_Exon5_Rep2_DMSO_patterns     3.514127  0.672250
#
#                                                       sub2       ins  \
# PCR17cycle_K562PE4K_HTS_Exon5_Rep1_DMSO_patterns  1.474589  0.224939
# PCR17cycle_K562PE4K_HTS_Exon5_Rep2_DMSO_patterns  1.538212  0.227054
# PCR20cycle_K562PE4K_HTS_Exon5_Rep1_DMSO_patterns  1.431946  0.210710
# PCR20cycle_K562PE4K_HTS_Exon5_Rep2_DMSO_patterns  1.579866  0.230889
# PCR23cycle_K562PE4K_HTS_Exon5_Rep1_DMSO_patterns  1.464259  0.211959
# PCR23cycle_K562PE4K_HTS_Exon5_Rep2_DMSO_patterns  1.594168  0.217793
#
#                                                        del      sub3  \
# PCR17cycle_K562PE4K_HTS_Exon5_Rep1_DMSO_patterns  0.206941  2.095405
# PCR17cycle_K562PE4K_HTS_Exon5_Rep2_DMSO_patterns  0.212147  2.111057
# PCR20cycle_K562PE4K_HTS_Exon5_Rep1_DMSO_patterns  0.207698  2.039951
# PCR20cycle_K562PE4K_HTS_Exon5_Rep2_DMSO_patterns  0.222521  2.241886
# PCR23cycle_K562PE4K_HTS_Exon5_Rep1_DMSO_patterns  0.216743  2.290381
# PCR23cycle_K562PE4K_HTS_Exon5_Rep2_DMSO_patterns  0.232750  2.284571
#
#                                                       sub4  sub5more   Complex
# PCR17cycle_K562PE4K_HTS_Exon5_Rep1_DMSO_patterns  3.851653  0.426247  0.003862
# PCR17cycle_K562PE4K_HTS_Exon5_Rep2_DMSO_patterns  3.688163  0.389406  0.003660
# PCR20cycle_K562PE4K_HTS_Exon5_Rep1_DMSO_patterns  3.610037  0.365694  0.003394
# PCR20cycle_K562PE4K_HTS_Exon5_Rep2_DMSO_patterns  4.017279  0.450233  0.004308
# PCR23cycle_K562PE4K_HTS_Exon5_Rep1_DMSO_patterns  3.839781  0.422056  0.003686
# PCR23cycle_K562PE4K_HTS_Exon5_Rep2_DMSO_patterns  4.092037  0.442868  0.004871

# %%
df_summary.to_csv('PCR_cycles_ReadPatterns.csv')

# %%
rpa = ReadPatternAnalyzer()

files = glob('data/frequency_table/K562PE4K_HTS2DoseControl*.txt')

for freq_table in tqdm(files,
                       total = len(files),
                       desc = 'Read Pattern Analyzer', ## 진행률 앞쪽 출력 문장
                       ncols = 100,                    ## 진행률 출력 폭 조절
                       ascii = ' =',                   ## 바 모양, 첫 번째 문자는 공백이어야 작동
                      ):
    
    sample   = os.path.basename(freq_table).replace('.txt', '')
    exon_num = sample.split('Exon')[1][0]
    ref_info = f'variants_info/ex{exon_num}_info.csv'

    df_out = rpa.run(freq_table, ref_info)
    df_out.to_csv(f'data/read_patterns/{sample}_patterns.csv', index=False)
# Out:
# Read Pattern Analyzer: 100%|==========================================| 2/2 [00:47<00:00, 23.67s/it]

# %%
# summary file 만들기

files = glob('data/read_patterns/K562PE4K_HTS2DoseControl*')
dict_summary = {}

for pattern_file in tqdm(files, total = len(files),
                       desc = 'Read Pattern Summary',  ## 진행률 앞쪽 출력 문장
                       ncols = 100,                    ## 진행률 출력 폭 조절
                       ascii = ' =',                   ## 바 모양, 첫 번째 문자는 공백이어야 작동
                      ):
    
    df_pattern  = pd.read_csv(pattern_file)
    sample_name = os.path.basename(pattern_file).replace('.csv', '')
    dict_temp   = {}

    for idx in tqdm(df_pattern.index, total=len(df_pattern.index),
                    desc='Summarize mut classes',
                    ncols=100,
                    leave=False,
                    ):
        data = df_pattern.loc[idx]

        try   : dict_temp[data.mut_class] += data['%Reads']
        except: dict_temp[data.mut_class]  = data['%Reads']

    dict_summary[sample_name] = dict_temp

df_summary = pd.DataFrame.from_dict(dict_summary, orient='index')
df_summary
# Out:
# Read Pattern Summary: 100%|===========================================| 2/2 [00:33<00:00, 16.90s/it]
#                                                     WT_refseq      SynPE  \
# K562PE4K_HTS2DoseControlDay10_Exon5_Rep1_DMSO_p...  53.632505  32.902781
# K562PE4K_HTS2DoseControlDay10_Exon5_Rep2_DMSO_p...  53.031354  33.123071
#
#                                                     Single_edit      sub1  \
# K562PE4K_HTS2DoseControlDay10_Exon5_Rep1_DMSO_p...     3.730768  0.672526
# K562PE4K_HTS2DoseControlDay10_Exon5_Rep2_DMSO_p...     3.767399  0.687600
#
#                                                         sub2       del  \
# K562PE4K_HTS2DoseControlDay10_Exon5_Rep1_DMSO_p...  1.528786  0.234672
# K562PE4K_HTS2DoseControlDay10_Exon5_Rep2_DMSO_p...  1.612260  0.243695
#
#                                                         ins      sub3  \
# K562PE4K_HTS2DoseControlDay10_Exon5_Rep1_DMSO_p...  0.21031  2.428246
# K562PE4K_HTS2DoseControlDay10_Exon5_Rep2_DMSO_p...  0.21757  2.501433
#
#                                                         sub4  sub5more  \
# K562PE4K_HTS2DoseControlDay10_Exon5_Rep1_DMSO_p...  4.186240  0.468829
# K562PE4K_HTS2DoseControlDay10_Exon5_Rep2_DMSO_p...  4.311158  0.499078
#
#                                                      Complex
# K562PE4K_HTS2DoseControlDay10_Exon5_Rep1_DMSO_p...  0.004339
# K562PE4K_HTS2DoseControlDay10_Exon5_Rep2_DMSO_p...  0.005383

# %%
df_summary.to_csv('PCR_cycles_ReadPatterns_26cycle.csv')
